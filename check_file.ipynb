# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
file_path = '/Users/anaralik/Documents/IISc/Project/Phase 2/Online Code/Crowd-movements-classification/Data/Crowd11_OpticalFlow/000125826.npy'
loaded_data = np.load(file_path)

# %%
file_path = '/Users/anaralik/Documents/IISc/Project/Phase 2/Online Code/Crowd-movements-classification/Data/Crowd11_OpticalFlow/055271257.npy'
loaded_data = np.load(file_path)

# %%
print(loaded_data.shape)
# Out:
# (614, 540, 960, 2)

# %%
fig, axs = plt.subplots(2, 3, figsize=(12, 6))

slice_index_0 = 400
slice_index_1 = 401
slice_index_2 = 402

axs[0,0].imshow(loaded_data[slice_index_0, :, :, 0], cmap='viridis')
axs[0,0].set_title(f'Slice at index {slice_index_0}')

axs[1,0].imshow(loaded_data[slice_index_0, :, :, 1], cmap='viridis')
axs[1,0].set_title(f'Slice at index {slice_index_0}')

axs[0,1].imshow(loaded_data[slice_index_1, :, :, 0], cmap='viridis')
axs[0,1].set_title(f'Slice at index {slice_index_1}')

axs[1,1].imshow(loaded_data[slice_index_1, :, :, 1], cmap='viridis')
axs[1,1].set_title(f'Slice at index {slice_index_1}')

axs[0,2].imshow(loaded_data[slice_index_2, :, :, 0], cmap='viridis')
axs[0,2].set_title(f'Slice at index {slice_index_2}')

axs[1,2].imshow(loaded_data[slice_index_2, :, :, 1], cmap='viridis')
axs[1,2].set_title(f'Slice at index {slice_index_2}')

plt.show()

# %%
video_path = "/Users/anaralik/Documents/IISc/Project/Phase 2/Online Code/Crowd-movements-classification/Data/Crowd-11/000125733.mp4"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Could not open video file.")

frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
cap.release()
print(f"Number of frames: {frame_count}")
print(f"Resolution: {width} x {height}")
# Out:
# Number of frames: 901
# Resolution: 960 x 540
